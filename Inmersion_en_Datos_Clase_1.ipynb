# %% [markdown]
# <a href="https://colab.research.google.com/github/MatiasRuizSilva/Python-for-Data-Science/blob/main/Inmersion_en_Datos_Clase_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###Primer encuentro de inmersion de datos

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
inmuebles = pd.read_csv('/content/drive/MyDrive/inmuebles_bogota.csv')
inmuebles.head()
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Baños  Área              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla            KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 3      2   154             Usaquén                                Usaquén
# 4      3   128         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
#
#              Valor
# 0    $ 360.000.000
# 1    $ 670.000.000
# 2  $ 1.120.000.000
# 3    $ 890.000.000
# 4    $ 970.000.000

# %%
inmuebles.shape
# Out:
# (9520, 8)

# %%
inmuebles.columns
# Out:
# Index(['Tipo', 'Descripcion', 'Habitaciones', 'Baños', 'Área', 'Barrio', 'UPZ',
#        'Valor'],
#       dtype='object')

# %%
columnas = {'Baños':'Banos','Área':'Area'}
inmuebles = inmuebles.rename(columns = columnas)
inmuebles.sample(10)
# Out:
#              Tipo                                 Descripcion  Habitaciones  \
# 9017  Apartamento                Apartamento en venta en Suba             3
# 123   Apartamento             Apartamento en venta en Usaquén             3
# 5222  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 4913         Casa                    Casa en venta en Modelia             5
# 2922  Apartamento            Apartamento en venta en Fontibón             2
# 176   Apartamento             Apartamento en venta en Usaquén             3
# 8366  Apartamento             Apartamento en venta en Usaquén             4
# 8059         Casa                       Casa en venta en Suba             4
# 6678  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 9361         Casa              Casa en venta en Puente Aranda             4
#
#       Banos  Area              Barrio  \
# 9017      2    80                Suba
# 123       2   100             Usaquén
# 5222      4   135  Zona Noroccidental
# 4913      4   320             Modelia
# 2922      2    52            Fontibón
# 176       4   100             Usaquén
# 8366      6   400             Usaquén
# 8059      2   100                Suba
# 6678      4    98  Zona Noroccidental
# 9361      2   230       Puente Aranda
#
#                                                  UPZ            Valor
# 9017                                            Suba    $ 286.000.000
# 123                                          Usaquén    $ 610.000.000
# 5222              CHAPINERO: Pardo Rubio + Chapinero    $ 680.000.000
# 4913                                        Fontibón    $ 750.000.000
# 2922                                        Fontibón    $ 150.000.000
# 176                                          Usaquén    $ 730.000.000
# 8366                                         Usaquén  $ 2.500.000.000
# 8059                                            Suba    $ 355.000.000
# 6678              CHAPINERO: Pardo Rubio + Chapinero    $ 601.000.000
# 9361  PUENTE ARANDA: Zona Industrial + Puente Aranda    $ 650.000.000

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 595.1+ KB
