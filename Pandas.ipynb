# %% [markdown]
# <a href="https://colab.research.google.com/github/MatiasRuizSilva/Python-for-Data-Science/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !python -V
# Out:
# Python 3.9.16

# %% [markdown]
# TRABAJANDO CON DATOS

# %%
import pandas as pd
pd.set_option('display.max_rows',4)
pd.set_option('display.max_columns',10)

# %%
dataset = pd.read_csv('alquiler.csv', sep = ';')

# %%
dataset
# Out:
#                   Tipo    Distrito  Cuartos  Vacantes  Suites  Area   Valor  \
# 0           Habitación   San Borja        1         0       0    40  1700.0
# 1                 Casa  Lurigancho        2         0       1   100  7000.0
# ...                ...         ...      ...       ...     ...   ...     ...
# 32958     Departamento       Rímac        2         0       0    70  3000.0
# 32959  Local comercial  Pachacámac        0         0       0   250  6500.0
#
#        Mantenimiento  Impuesto
# 0              500.0      60.0
# 1                NaN       NaN
# ...              ...       ...
# 32958          760.0       NaN
# 32959         4206.0    1109.0
#
# [32960 rows x 9 columns]

# %%
dataset.describe()
# Out:
#            Cuartos      Vacantes        Suites          Area         Valor  \
# count  32960.00000  32960.000000  32960.000000  32960.000000  3.294300e+04
# mean       1.77139      1.749059      0.665777    231.901547  1.295266e+04
# ...            ...           ...           ...           ...           ...
# 75%        3.00000      2.000000      1.000000    170.000000  6.500000e+03
# max      100.00000   1966.000000     70.000000  90000.000000  1.200000e+08
#
#        Mantenimiento      Impuesto
# count   2.886700e+04  2.272300e+04
# mean    2.388062e+03  2.364410e+03
# ...              ...           ...
# 75%     1.800000e+03  6.970000e+02
# max     6.552570e+06  2.705307e+07
#
# [8 rows x 7 columns]

# %%
datos = pd.read_csv('alquiler.csv', sep = ';')
datos
# Out:
#                   Tipo    Distrito  Cuartos  Vacantes  Suites  Area   Valor  \
# 0           Habitación   San Borja        1         0       0    40  1700.0
# 1                 Casa  Lurigancho        2         0       1   100  7000.0
# ...                ...         ...      ...       ...     ...   ...     ...
# 32958     Departamento       Rímac        2         0       0    70  3000.0
# 32959  Local comercial  Pachacámac        0         0       0   250  6500.0
#
#        Mantenimiento  Impuesto
# 0              500.0      60.0
# 1                NaN       NaN
# ...              ...       ...
# 32958          760.0       NaN
# 32959         4206.0    1109.0
#
# [32960 rows x 9 columns]
